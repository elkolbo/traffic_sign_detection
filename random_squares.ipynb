# %%
import os
import random
import cv2
import numpy as np
from PIL import Image, ImageDraw


def process_images(folder_path, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    k = 0
    # Iterate through each image in the input folder
    for filename in os.listdir(folder_path):
        if filename.endswith((".png", ".jpg", ".jpeg")):
            # Open the image
            image_path = os.path.join(folder_path, filename)
            image = Image.open(image_path)

            # Choose 40 random squares, resize them, and draw on the new image
            for i in range(25):
                x = random.randint(0, image.width - 40)
                y = random.randint(0, image.height - 40)
                size = random.randint(20, 60)

                # Specify red color
                color = (255, 0, 0)

                square = [x, y, x + size, y + size]

                # Create a new image to draw squares on
                draw_image = image.copy()
                draw = ImageDraw.Draw(draw_image)
                draw.rectangle(square, outline=color, width=2)

                # Draw a red line connecting the small image to its position in the larger image
                draw.line(
                    [(image.width, 75), (x + size, y + size / 2)],
                    fill=color,
                    width=4,
                )

                # Display the original image with squares overlaid
                display_image = np.array(draw_image)

                # Create the small padded image
                square_image = image.crop(square).resize((150, 150))
                square_image_save = image.crop(square).resize((50, 50))
                square_np = np.array(square_image)
                pad_height = max(0, display_image.shape[0] - square_np.shape[0])
                padded_square = np.pad(
                    square_np, ((0, pad_height), (0, 0), (0, 0)), mode="constant"
                )

                # Ensure both images have the same height before stacking horizontally
                min_height = min(display_image.shape[0], padded_square.shape[0])
                combined_image = np.hstack(
                    (display_image[:min_height], padded_square[:min_height])
                )

                cv2.imshow(
                    "Combined Image", cv2.cvtColor(combined_image, cv2.COLOR_RGB2BGR)
                )
                key = cv2.waitKey(0) & 0xFF

                # Check the key pressed by the user
                if key == ord("s"):
                    # Save the square as a new image
                    output_filename = (
                        f"{i +k+ 1}" + "_" + str(random.randint(0, 1000)) + ".jpg"
                    )
                    output_path = os.path.join(output_folder, output_filename)
                    square_image_save.save(output_path)
                    print(f"Image {i +k+ 1} saved.")
                elif key == ord("l"):
                    print(f"Image {i +k+ 1} discarded.")
                elif key == ord("q"):
                    cv2.destroyAllWindows()
                    print("Processing stopped.")
                    return

            k = k + 100

    cv2.destroyAllWindows()
    print("Processing complete.")


# Example usage:
input_folder = (
    r"C:\Users\loren\Documents\AI_BME\Data Challenge\traffic_sign_detection\test_images"
)
output_folder = r"C:\Users\loren\Documents\AI_BME\Data Challenge\traffic_sign_detection\randomimagescrops"
process_images(input_folder, output_folder)
# Out:
# Image 1 saved.
# Image 2 saved.
# Image 3 saved.
# Image 4 saved.
# Image 5 saved.
# Image 6 saved.
# Image 7 saved.
# Image 8 saved.
# Image 9 saved.
# Image 10 saved.
# Image 11 discarded.
# Image 12 saved.
# Image 13 saved.
# Image 14 saved.
# Image 15 saved.
# Image 16 saved.
# Image 17 saved.
# Image 18 saved.
# Image 19 saved.
# Image 20 saved.
# Image 21 saved.
# Image 22 saved.
# Image 23 saved.
# Image 24 saved.
# Image 25 saved.
# Image 101 saved.
# Image 102 saved.
# Image 103 saved.
# Image 104 saved.
# Image 105 saved.
# Image 106 saved.
# Image 107 saved.
# Image 108 discarded.
# Image 109 discarded.
# Image 110 saved.
# Image 111 saved.
# Image 112 saved.
# Image 113 saved.
# Image 114 saved.
# Image 115 discarded.
# Image 116 saved.
# Image 117 saved.
# Image 118 saved.
# Image 119 saved.
# Image 120 saved.
# Image 121 saved.
# Image 122 saved.
# Image 123 saved.
# Image 124 saved.
# Image 125 saved.
# Image 201 saved.
# Image 202 saved.
# Image 203 saved.
# Image 204 discarded.
# Image 205 saved.
# Image 206 saved.
# Image 207 saved.
# Image 208 saved.
# Image 209 saved.
# Image 210 saved.
# Image 211 saved.
# Image 212 saved.
# Image 213 saved.
# Image 214 saved.
# Image 215 saved.
# Image 216 saved.
# Image 217 saved.
# Image 218 saved.
# Image 219 saved.
# Image 220 saved.
# Image 221 saved.
# Image 222 saved.
# Image 223 saved.
# Image 224 saved.
# Image 225 saved.
# Image 301 saved.
# Image 302 saved.
# Image 303 saved.
# Image 304 saved.
# Image 305 saved.
# Image 306 saved.
# Image 307 saved.
# Image 308 saved.
# Image 309 saved.
# Image 310 saved.
# Image 311 saved.
# Image 312 saved.
# Image 313 saved.
# Image 314 saved.
# Image 315 saved.
# Image 316 saved.
# Image 317 saved.
# Image 318 saved.
# Image 319 saved.
# Image 320 saved.
# Image 321 saved.
# Image 322 saved.
# Image 323 saved.
# Image 324 saved.
# Image 325 saved.
# Image 401 saved.
# Image 402 saved.
# Image 403 saved.
# Image 404 saved.
# Image 405 saved.
# Image 406 saved.
# Image 407 saved.
# Image 408 saved.
# Image 409 saved.
# Image 410 discarded.
# Image 411 saved.
# Image 412 saved.
# Image 413 saved.
# Image 414 saved.
# Image 415 saved.
# Image 416 saved.
# Image 417 saved.
# Image 418 saved.
# Image 419 saved.
# Image 420 saved.
# Image 421 saved.
# Image 422 saved.
# Image 423 saved.
# Image 424 saved.
# Image 425 saved.
# Image 501 saved.
# Image 502 saved.
# Image 503 saved.
# Image 504 saved.
# Image 505 saved.
# Image 506 saved.
# Image 507 saved.
# Image 508 saved.
# Image 509 saved.
# Image 510 saved.
# Image 511 saved.
# Image 512 saved.
# Image 513 saved.
# Image 514 saved.
# Image 515 saved.
# Image 516 saved.
# Image 517 saved.
# Image 518 saved.
# Image 519 saved.
# Image 520 saved.
# Image 521 discarded.
# Image 522 saved.
# Image 523 saved.
# Image 524 saved.
# Image 525 saved.
# Image 601 saved.
# Image 602 saved.
# Image 603 saved.
# Image 604 saved.
# Image 605 saved.
# Image 606 saved.
# Image 607 saved.
# Image 608 saved.
# Image 609 saved.
# Image 610 saved.
# Image 611 saved.
# Image 612 saved.
# Image 613 saved.
# Image 614 saved.
# Image 615 saved.
# Image 616 saved.
# Image 617 saved.
# Image 618 saved.
# Image 619 saved.
# Image 620 saved.
# Image 621 saved.
# Image 622 saved.
# Image 623 saved.
# Image 624 saved.
# Image 625 saved.
# Image 701 saved.
# Image 702 saved.
# Image 703 discarded.
# Image 704 saved.
# Image 705 saved.
# Image 706 saved.
# Image 707 saved.
# Image 708 saved.
# Image 709 saved.
# Image 710 saved.
# Image 711 saved.
# Image 712 saved.
# Image 713 saved.
# Image 714 saved.
# Image 715 saved.
# Image 716 saved.
# Image 717 saved.
# Image 718 saved.
# Image 719 saved.
# Image 720 discarded.
# Image 721 saved.
# Image 722 saved.
# Image 723 discarded.
# Image 724 saved.
# Image 725 saved.
# Image 801 saved.
# Image 802 saved.
# Image 803 saved.
# Image 804 saved.
# Image 805 saved.
# Image 806 saved.
# Image 807 saved.
# Image 808 saved.
# Image 809 discarded.
# Image 810 saved.
# Image 811 discarded.
# Image 812 saved.
# Image 813 saved.
# Image 814 discarded.
# Image 815 saved.
# Image 816 saved.
# Image 817 saved.
# Image 818 saved.
# Image 819 saved.
# Image 820 saved.
# Image 821 discarded.
# Image 822 saved.
# Image 823 saved.
# Image 824 saved.
# Image 825 saved.
# Image 901 saved.
# Image 902 saved.
# Image 903 saved.
# Image 904 saved.
# Image 905 saved.
# Image 906 saved.
# Image 907 saved.
# Image 908 saved.
# Image 909 saved.
# Image 910 saved.
# Image 911 saved.
# Image 912 saved.
# Image 913 saved.
# Image 914 saved.
# Image 915 saved.
# Image 916 saved.
# Image 917 saved.
# Image 918 saved.
# Image 919 saved.
# Image 920 saved.
# Image 921 saved.
# Image 922 saved.
# Image 923 saved.
# Image 924 saved.
# Image 925 saved.
# Image 1001 saved.
# Image 1002 saved.
# Image 1003 saved.
# Image 1004 saved.
# Image 1005 saved.
# Image 1006 saved.
# Image 1007 saved.
# Image 1008 saved.
# Image 1009 saved.
# Image 1010 saved.
# Image 1011 saved.
# Image 1012 saved.
# Image 1013 saved.
# Image 1014 saved.
# Image 1015 saved.
# Image 1016 saved.
# Image 1017 discarded.
# Image 1018 saved.
# Image 1019 saved.
# Image 1020 saved.
# Image 1021 saved.
# Image 1022 saved.
# Image 1023 saved.
# Image 1024 saved.
# Image 1025 discarded.
# Image 1101 saved.
# Image 1102 saved.
# Image 1103 saved.
# Image 1104 saved.
# Image 1105 saved.
# Image 1106 saved.
# Image 1107 saved.
# Image 1108 discarded.
# Image 1109 saved.
# Image 1110 saved.
# Image 1111 saved.
# Image 1112 saved.
# Image 1113 saved.
# Image 1114 saved.
# Image 1115 saved.
# Image 1116 saved.
# Image 1117 saved.
# Image 1118 saved.
# Image 1119 saved.
# Image 1120 saved.
# Image 1121 saved.
# Image 1122 saved.
# Image 1123 discarded.
# Image 1124 saved.
# Image 1125 saved.
# Image 1201 saved.
# Image 1202 saved.
# Image 1203 discarded.
# Image 1204 saved.
# Image 1205 saved.
# Image 1206 saved.
# Image 1207 saved.
# Image 1208 saved.
# Image 1209 saved.
# Image 1210 saved.
# Image 1211 discarded.
# Image 1212 saved.
# Image 1213 saved.
# Image 1214 saved.
# Image 1215 saved.
# Image 1216 saved.
# Image 1217 saved.
# Image 1218 saved.
# Image 1219 saved.
# Image 1220 saved.
# Image 1221 saved.
# Image 1222 saved.
# Image 1223 saved.
# Image 1224 saved.
# Image 1225 saved.
# Image 1301 saved.
# Image 1302 saved.
# Image 1303 discarded.
# Image 1304 saved.
# Image 1305 saved.
# Image 1306 saved.
# Image 1307 saved.
# Image 1308 saved.
# Image 1309 saved.
# Image 1310 saved.
# Image 1311 saved.
# Image 1312 discarded.
# Image 1313 saved.
# Image 1314 saved.
# Image 1315 saved.
# Image 1316 saved.
# Image 1317 saved.
# Image 1318 saved.
# Image 1319 saved.
# Image 1320 saved.
# Image 1321 saved.
# Image 1322 saved.
# Image 1323 saved.
# Image 1324 saved.
# Image 1325 saved.
# Image 1401 saved.
# Image 1402 saved.
# Image 1403 saved.
# Image 1404 saved.
# Image 1405 saved.
# Image 1406 saved.
# Image 1407 saved.
# Image 1408 saved.
# Image 1409 saved.
# Image 1410 saved.
# Image 1411 saved.
# Image 1412 saved.
# Image 1413 saved.
# Image 1414 saved.
# Image 1415 saved.
# Image 1416 saved.
# Image 1417 saved.
# Image 1418 saved.
# Image 1419 saved.
# Image 1420 saved.
# Image 1421 discarded.
# Image 1422 discarded.
# Image 1423 saved.
# Image 1424 saved.
# Image 1425 saved.
# Image 1501 saved.
# Image 1502 saved.
# Image 1503 saved.
# Image 1504 saved.
# Image 1505 saved.
# Image 1506 saved.
# Image 1507 saved.
# Image 1508 discarded.
# Image 1509 saved.
# Image 1510 saved.
# Image 1511 saved.
# Image 1512 saved.
# Image 1513 saved.
# Image 1514 saved.
# Image 1515 saved.
# Image 1516 saved.
# Image 1517 saved.
# Image 1518 saved.
# Image 1519 saved.
# Image 1520 saved.
# Image 1521 saved.
# Image 1522 saved.
# Image 1523 saved.
# Image 1524 saved.
# Image 1525 saved.
# Image 1601 saved.
# Image 1602 saved.
# Image 1603 saved.
# Image 1604 saved.
# Image 1605 saved.
# Image 1606 saved.
# Image 1607 discarded.
# Image 1608 saved.
# Image 1609 saved.
# Image 1610 saved.
# Image 1611 discarded.
# Image 1612 saved.
# Image 1613 saved.
# Image 1614 saved.
# Image 1615 saved.
# Image 1616 saved.
# Image 1617 saved.
# Image 1618 saved.
# Image 1619 saved.
# Image 1620 saved.
# Image 1621 saved.
# Image 1622 saved.
# Image 1623 saved.
# Image 1624 saved.
# Image 1625 saved.
# Image 1701 saved.
# Image 1702 saved.
# Image 1703 saved.
# Image 1704 saved.
# Image 1705 saved.
# Image 1706 saved.
# Image 1707 saved.
# Image 1708 saved.
# Image 1709 saved.
# Image 1710 saved.
# Image 1711 discarded.
# Image 1712 saved.
# Image 1713 saved.
# Image 1714 saved.
# Image 1715 saved.
# Image 1716 saved.
# Image 1717 saved.
# Image 1718 saved.
# Image 1719 saved.
# Image 1720 discarded.
# Image 1721 saved.
# Image 1722 saved.
# Image 1723 saved.
# Image 1724 discarded.
# Image 1725 saved.
# Image 1801 saved.
# Image 1802 saved.
# Image 1803 saved.
# Image 1804 saved.
# Image 1805 saved.
# Image 1806 saved.
# Image 1807 saved.
# Image 1808 saved.
# Image 1809 saved.
# Image 1810 saved.
# Image 1811 saved.
# Image 1812 saved.
# Image 1813 saved.
# Image 1814 saved.
# Image 1815 saved.
# Image 1816 saved.
# Image 1817 saved.
# Image 1818 saved.
# Image 1819 saved.
# Image 1820 saved.
# Image 1821 saved.
# Image 1822 saved.
# Image 1823 saved.
# Image 1824 saved.
# Image 1825 saved.
# Image 1901 saved.
# Image 1902 saved.
# Image 1903 saved.
# Image 1904 saved.
# Image 1905 saved.
# Image 1906 saved.
# Image 1907 saved.
# Image 1908 saved.
# Image 1909 saved.
# Image 1910 saved.
# Image 1911 saved.
# Image 1912 saved.
# Image 1913 saved.
# Image 1914 saved.
# Image 1915 saved.
# Image 1916 saved.
# Image 1917 saved.
# Image 1918 saved.
# Image 1919 saved.
# Image 1920 saved.
# Image 1921 saved.
# Image 1922 saved.
# Image 1923 saved.
# Image 1924 saved.
# Image 1925 saved.
# Processing complete.

# %%
# Out:
# Processing stopped.

# %%
# Out:
# Processing stopped.
